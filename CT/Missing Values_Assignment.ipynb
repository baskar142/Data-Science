# %%
import pandas as pd

# %%
df =pd.read_csv("kidney_disease.csv")

# %%
df.head(10)
# Out:
#    id   age     bp     sg   al   su       rbc        pc         pcc  \
# 0   0  48.0   80.0  1.020  1.0  0.0       NaN    normal  notpresent
# 1   1   7.0   50.0  1.020  4.0  0.0       NaN    normal  notpresent
# 2   2  62.0   80.0  1.010  2.0  3.0    normal    normal  notpresent
# 3   3  48.0   70.0  1.005  4.0  0.0    normal  abnormal     present
# 4   4  51.0   80.0  1.010  2.0  0.0    normal    normal  notpresent
# 5   5  60.0   90.0  1.015  3.0  0.0       NaN       NaN  notpresent
# 6   6  68.0   70.0  1.010  0.0  0.0       NaN    normal  notpresent
# 7   7  24.0    NaN  1.015  2.0  4.0    normal  abnormal  notpresent
# 8   8  52.0  100.0  1.015  3.0  0.0    normal  abnormal     present
# 9   9  53.0   90.0  1.020  2.0  0.0  abnormal  abnormal     present
#
#            ba  ...  pcv     wc   rc  htn   dm  cad appet   pe  ane  \
# 0  notpresent  ...   44   7800  5.2  yes  yes   no  good   no   no
# 1  notpresent  ...   38   6000  NaN   no   no   no  good   no   no
# ...

# %%
df['pcv'].isnull().sum()
# Out:
# 70

# %%
df.isnull().sum()
# Out:
# id                  0
# age                 9
# bp                 12
# sg                 47
# al                 46
# su                 49
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# bgr                44
# bu                 19
# sc                 17
# sod                87
# pot                88
# hemo               52
# pcv                70
# wc                105
# rc                130
# htn                 2
# dm                  2
# cad                 2
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %%
df.shape
# Out:
# (400, 26)

# %% [markdown]
# # Dropping Rows with Missing Values

# %%
df_dropna = df.dropna()
print("Dataset after dropping rows with missing values:")

print(df_dropna.shape)
df_dropna
# Out:
# Dataset after dropping rows with missing values:
# (159, 26)
#       id   age    bp     sg   al   su       rbc        pc         pcc  \
# 3      3  48.0  70.0  1.005  4.0  0.0    normal  abnormal     present
# 9      9  53.0  90.0  1.020  2.0  0.0  abnormal  abnormal     present
# 11    11  63.0  70.0  1.010  3.0  0.0  abnormal  abnormal     present
# 14    14  68.0  80.0  1.010  3.0  2.0    normal  abnormal     present
# 20    20  61.0  80.0  1.015  2.0  0.0  abnormal  abnormal  notpresent
# ..   ...   ...   ...    ...  ...  ...       ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0    normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0    normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0    normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0    normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0    normal    normal  notpresent
#
# ...

# %% [markdown]
# # Dropping Columns with Missing Values

# %%
#2. Remove Columns with Missing Values

df_dropna_columns = df.dropna(axis=1)
print("Data after dropping columns with missing values:")
print(df_dropna_columns)
df_dropna_columns
# Out:
# Data after dropping columns with missing values:
#       id   age classification
# 0      0  48.0            ckd
# 1      1   7.0            ckd
# 2      2  62.0            ckd
# 3      3  48.0            ckd
# 4      4  51.0            ckd
# ..   ...   ...            ...
# 395  395  55.0         notckd
# 396  396  42.0         notckd
# 397  397  12.0         notckd
# 398  398  17.0         notckd
# 399  399  58.0         notckd
#
# [400 rows x 3 columns]
#       id   age classification
# 0      0  48.0            ckd
# 1      1   7.0            ckd
# 2      2  62.0            ckd
# 3      3  48.0            ckd
# 4      4  51.0            ckd
# ..   ...   ...            ...
# 395  395  55.0         notckd
# 396  396  42.0         notckd
# 397  397  12.0         notckd
# 398  398  17.0         notckd
# 399  399  58.0         notckd
#
# [400 rows x 3 columns]

# %%
def QuanQual(df):
    quan=[]
    qual=[]
    for columnName in df.columns:
        
    #print col
        #print(columnName)
        if(df[columnName].dtype=='O'):
        #print qual
            #print("qual")
            qual.append(columnName)
        else:
        #print quan
            #print("quan")
            quan.append(columnName)
    return quan, qual

# %%
quan, qual =QuanQual(df)
print("Quantitive_variables:",quan)
print("Quantitive_variables:",qual)
# Out:
# Quantitive_variables: ['id', 'age', 'bp', 'sg', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hemo']
# Quantitive_variables: ['rbc', 'pc', 'pcc', 'ba', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad', 'appet', 'pe', 'ane', 'classification']

# %% [markdown]
# # SimpleImputer libaray replacing null values with mean

# %%
# SimpleImputer libaray replacing null values with mean
import numpy as np
from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values=np.nan, strategy='mean')
df[quan] = imp.fit_transform(df[quan])
print(df)
# Out:
#         id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0.0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1      1.0   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2      2.0  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3.0  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4.0  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..     ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395.0  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396.0  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397.0  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398.0  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399.0  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# ...

# %% [markdown]
# # Replacing Null values with mean

# %%
# List of numerical columns
numeric_cols = ['age', 'bp', 'sg', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hemo']

# Convert columns to numeric type
df[numeric_cols] = df[numeric_cols].apply(pd.to_numeric, errors='coerce')

# Fill NaN values with mean
for col in numeric_cols:
    df[col].fillna(df[col].mean(), inplace=True)

print(df)
# Out:
#       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# 0    notpresent  ...   44  7800  5.2  yes  yes   no  good   no   no
# ...

# %% [markdown]
# # Replacing Null values with mode

# %%
# List of numerical columns
numeric_cols = ['age', 'bp', 'sg', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hemo']

# Convert columns to numeric type
df[numeric_cols] = df[numeric_cols].apply(pd.to_numeric, errors='coerce')

# Fill NaN values with mode
for col in numeric_cols:
    df[col].fillna(df[col].mode(), inplace=True)

print(df)
# Out:
#       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# 0    notpresent  ...   44  7800  5.2  yes  yes   no  good   no   no
# ...

# %% [markdown]
# # SimpleImputer to fill null values for qualitative  variables

# %%
#usuing SimpleImputer libaray replacing categorical null values with mode
import numpy as np
from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
df[qual] = imp.fit_transform(df[qual])
print(df)
# Out:
#       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0  normal    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0  normal    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# 0    notpresent  ...   44  7800  5.2  yes  yes   no  good   no   no
# ...

# %% [markdown]
# # Impute with Forward Fill

# %%
df_ffill = df.fillna(method='ffill')
print("Data after forward filling missing values:")
print(df_ffill)
# Out:
# Data after forward filling missing values:
#       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# ...

# %% [markdown]
# # Impute with Backward Fill

# %%
df_bfill = df.fillna(method='bfill')
print("Data after backward filling missing values:")
print(df_bfill)
# Out:
# Data after backward filling missing values:
#       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0  normal    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0  normal    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# ...

# %% [markdown]
# # K-Nearest Neighbors Imputation

# %%
# Initialize the KNN imputer
knn_imputer = KNNImputer(n_neighbors=3)

# Apply the KNN imputer
df_knn_imputed = pd.DataFrame(knn_imputer.fit_transform(df[quan]), columns=quan)

# Fill back the imputed values to the original DataFrame
df[quan] = df_knn_imputed

print("Data after KNN imputation:")
print(df)
# Out:
# Data after KNN imputation:
#         id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0.0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1      1.0   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2      2.0  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3.0  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4.0  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..     ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395.0  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396.0  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397.0  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398.0  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399.0  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# ...
